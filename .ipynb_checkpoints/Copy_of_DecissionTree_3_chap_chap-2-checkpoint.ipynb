# %%
 # Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/My Drive/intrusiondetectionkit/ids-train.csv')

# %%
data.head()
# Out:
#   duration protocol_type count  ... diff_srv_rate srv_diff_host_rate   class
# 0     zero           tcp  one+  ...          zero               zero  normal
# 1     zero           tcp  one+  ...          zero               zero  normal
# 2     zero           tcp  one+  ...          zero               zero  normal
# 3     zero           tcp  one+  ...          zero               zero  normal
# 4     zero           tcp  one+  ...          zero               zero  normal
#
# [5 rows x 12 columns]

# %%
data2=data.iloc[:,11:]
data2
# Out:
#        class
# 0     normal
# 1     normal
# 2     normal
# 3     normal
# 4     normal
# ..       ...
# 795  neptune
# 796  neptune
# 797  neptune
# 798  neptune
# 799  neptune
#
# [800 rows x 1 columns]

# %%
data1=data.iloc[:,:-1]
data1
# Out:
#     duration protocol_type  ... diff_srv_rate srv_diff_host_rate
# 0       zero           tcp  ...          zero               zero
# 1       zero           tcp  ...          zero               zero
# 2       zero           tcp  ...          zero               zero
# 3       zero           tcp  ...          zero               zero
# 4       zero           tcp  ...          zero               zero
# ..       ...           ...  ...           ...                ...
# 795     zero           tcp  ...          zero               zero
# 796     zero           tcp  ...          zero               zero
# 797     zero           tcp  ...          zero               zero
# 798     zero           tcp  ...          zero               zero
# 799     zero           tcp  ...          zero               zero
#
# [800 rows x 11 columns]

# %%
#converting all data to numeric
from sklearn.preprocessing import LabelEncoder
labelencoder_df=LabelEncoder()
data1=data1.apply(LabelEncoder().fit_transform)
data1
# Out:
#      duration  protocol_type  ...  diff_srv_rate  srv_diff_host_rate
# 0           2              0  ...              4                   5
# 1           2              0  ...              4                   5
# 2           2              0  ...              4                   5
# 3           2              0  ...              4                   5
# 4           2              0  ...              4                   5
# ..        ...            ...  ...            ...                 ...
# 795         2              0  ...              4                   5
# 796         2              0  ...              4                   5
# 797         2              0  ...              4                   5
# 798         2              0  ...              4                   5
# 799         2              0  ...              4                   5
#
# [800 rows x 11 columns]

# %%
data3=pd.concat([data1, data2], axis=1, sort=False)
data3
# Out:
#      duration  protocol_type  count  ...  diff_srv_rate  srv_diff_host_rate    class
# 0           2              0      1  ...              4                   5   normal
# 1           2              0      1  ...              4                   5   normal
# 2           2              0      1  ...              4                   5   normal
# 3           2              0      1  ...              4                   5   normal
# 4           2              0      1  ...              4                   5   normal
# ..        ...            ...    ...  ...            ...                 ...      ...
# 795         2              0      2  ...              4                   5  neptune
# 796         2              0      2  ...              4                   5  neptune
# 797         2              0      2  ...              4                   5  neptune
# 798         2              0      2  ...              4                   5  neptune
# ...

# %%
#split dataset in features and target variable
feature_cols = ['duration', 'protocol_type', 'count', 'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate','diff_srv_rate', 'srv_diff_host_rate']
label=['class']
X = data3[feature_cols] # Features
y = data3[label] # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
dlf_ = DecisionTreeClassifier(criterion="entropy", max_depth=800)

# Train Decision Tree Classifer
dlf_.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = dlf_.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
#visualization
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(dlf_, out_file=dot_data, filled=True, rounded=True, special_characters=True,feature_names = feature_cols)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('KDDcup.png')
Image(graph.create_png())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
